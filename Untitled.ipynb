# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from IPython.core.display import HTML
from IPython.core.pylabtools import figsize

# %%
figsize(5, 4)
plt.rcParams.update({'font.size': 11})

# %%
power = np.arange(-15, 0)

# %%
BER = [2.06e-01, 1.72e-01, 1.45e-01, 1.22e-01, 1.02e-01, 8.67e-02, 7.38e-02, 6.56e-02, 6.01e-02, 5.68e-02, 5.47e-02, 5.27e-02, 5.13e-02, 5.05e-02, 5.05e-02]
BERNN = [2.11e-01, 1.76e-01, 1.46e-01, 1.19e-01, 9.53e-02, 7.66e-02, 6.27e-02, 5.42e-02, 4.92e-02, 4.67e-02, 4.50e-02, 4.38e-02, 4.31e-02, 4.27e-02, 4.25e-02]
BERNNC = [2.05e-01, 1.70e-01, 1.42e-01, 1.17e-01, 9.61e-02, 7.87e-02, 6.46e-02, 5.57e-02, 4.95e-02, 4.65e-02, 4.49e-02, 4.36e-02, 4.28e-02, 4.24e-02, 4.23e-02]

# %%
plt.plot(power, np.log10(BER),'>-', label='BER',linewidth = 2)
plt.plot(power, np.log10(BERNN),'-s', label='BER s/ transfer learning', color = 'black', linewidth = 2)
plt.plot(power, np.log10(BERNNC), '-o', label = "BER c/ transfer learning", linewidth = 2)
plt.grid()
plt.legend();
plt.title('BER x Pi_dBm - 4 km')
plt.xlabel('Pi (dBm)')
plt.ylabel('log10(BER)')
# Out:
# Text(0, 0.5, 'log10(BER)')

# %%
BER3 = [1.94e-01, 1.61e-01, 1.34e-01, 1.10e-01,  8.99e-02, 7.40e-02, 6.24e-02, 5.32e-02, 4.92e-02, 4.57e-02, 4.45e-02, 4.33e-02, 4.28e-02, 4.21e-02, 4.19e-02]
BERNN3 = [1.94e-01, 1.61e-01, 1.35e-01, 1.11e-01, 9.17e-02, 7.57e-02, 6.36e-02, 5.46e-02, 4.92e-02, 4.57e-02, 4.39e-02, 4.27e-02, 4.25e-02, 4.26e-02, 4.23e-02]
BERNNC3 = [1.69e-01, 1.40e-01, 1.17e-01, 9.91e-02, 8.68e-02, 7.76e-02, 7.11e-02, 6.74e-02, 6.66e-02, 6.46e-02, 6.34e-02, 6.41e-02, 6.33e-02, 6.44e-02, 6.41e-02]

# %%
plt.plot(power, np.log10(BER3),'>-', label='BER',linewidth = 2)
plt.plot(power, np.log10(BERNN3),'-s', label='BER s/ transfer learning', color = 'black', linewidth = 2)
plt.plot(power, np.log10(BERNNC3), '-o', label = "BER c/ transfer learning", linewidth = 2)
plt.grid()
plt.legend();
plt.title('BER x Pi_dBm - 3 km')
plt.xlabel('Pi (dBm)')
plt.ylabel('log10(BER)')
# Out:
# Text(0, 0.5, 'log10(BER)')

# %%
BER5 = [2.22e-01, 1.89e-01, 1.62e-01, 1.39e-01, 1.23e-01, 1.08e-01, 9.57e-02, 8.92e-02, 8.33e-02, 8.06e-02, 7.82e-02, 7.73e-02, 7.54e-02, 7.38e-02, 7.46e-02]
BERNN5 = [2.23e-01, 1.86e-01, 1.55e-01, 1.28e-01, 1.05e-01, 8.49e-02, 6.89e-02, 5.98e-02, 5.37e-02, 5.01e-02, 4.83e-02, 4.74e-02, 4.57e-02, 4.50e-02, 4.52e-02]
BERNNC5 = [2.20e-01, 1.84e-01, 1.55e-01, 1.30e-01, 1.09e-01, 9.03e-02, 7.41e-02, 6.52e-02, 5.80e-02, 5.36e-02, 5.17e-02, 5.04e-02, 4.88e-02, 4.88e-02, 4.81e-02]

# %%
plt.plot(power, np.log10(BER5),'>-', label='BER',linewidth = 2)
plt.plot(power, np.log10(BERNN5),'-s', label='BER s/ transfer learning', color = 'black', linewidth = 2)
plt.plot(power, np.log10(BERNNC5), '-o', label = "BER c/ transfer learning", linewidth = 2)
plt.grid()
plt.legend();
plt.title('BER x Pi_dBm - 5 km')
plt.xlabel('Pi (dBm)')
plt.ylabel('log10(BER)')
# Out:
# Text(0, 0.5, 'log10(BER)')
